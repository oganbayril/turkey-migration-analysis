# %%
import pandas as pd
from pathlib import Path
from IPython.display import display

# %%
data_dir = Path('../data/raw')

datasets = {
    'Applications from turkey': pd.read_csv(data_dir / 'asylum_applications_originating_tur.csv'),
    'Applications to turkey': pd.read_csv(data_dir / 'asylum_applications_residing_tur.csv'),
    'Decisions from turkey': pd.read_csv(data_dir / 'asylum_decisions_residing_tur.csv'),
    'Decisions from other countries': pd.read_csv(data_dir / 'asylum_decisions_originating_tur.csv'),
}

applications_datasets = {
    'Applications from turkey': datasets['Applications from turkey'],
    'Applications to turkey': datasets['Applications to turkey']
}

decisions_datasets = {
    'Decisions from turkey': datasets['Decisions from turkey'],
    'Decisions from other countries': datasets['Decisions from other countries']
}

print('Data loaded successfully')
print(f"Number of datasets loaded: {len(datasets)}" )
# Out:
# Data loaded successfully
# Number of datasets loaded: 4

# %%
# Display basic information about each dataset

for name, df in datasets.items():
    print('-' * 50)
    print(f"\nDataset: {name}")
    print(f"Number of rows: {len(df)}")
    print(f"Number of columns: {len(df.columns)}")
    
    print('First few rows:')
    display(df.head())
print('-' * 50)
# Out:
# --------------------------------------------------
#
# Dataset: Applications from turkey
# Number of rows: 1786
# Number of columns: 13
# First few rows:
#          Year Country of Origin Code Country of Asylum Code  \
# 0  #date+year   #country+code+origin   #country+code+asylum
# 1        2000                    TUR                    ALB
# 2        2000                    TUR                    AUS
# 3        2000                    TUR                    AUS
# 4        2000                    TUR                    AUT
#
#   Country of Origin Name Country of Asylum Name             Procedure Type  \
# 0   #country+name+origin   #country+name+asylum  #indicator+procedure_type
# 1                Türkiye                Albania                          G
# 2                Türkiye              Australia                          G
# 3                Türkiye              Australia                          G
# 4                Türkiye                Austria                          G
#
#               Procedure Name             Application Type Code  \
# 0  #indicator+procedure+name  #indicator+application_type+code
# 1                 Government                                 V
# 2                 Government                                 V
# 3                 Government                                 V
# 4                 Government                                 V
#
#               Application Type             Application Data Type  \
# 0  #indicator+application_type  #indicator+application_data_type
# 1                      Various                                 C
# 2                      Various                                 C
# 3                      Various                                 C
# 4                      Various                                 P
#
#               Application Data        Application Average Persons Per Case  \
# 0  #indicator+application_data  #indicator+application_average_persons+num
# 1                        Cases                                           0
# 2                        Cases                                           0
# 3                        Cases                                           0
# 4                      Persons                                           0
#
#                 Number of Applications
# 0  #inneed+asylum_seekers+applications
# 1                                   34
# 2                                   75
# 3                                  111
# 4                                  592
# --------------------------------------------------
#
# Dataset: Applications to turkey
# Number of rows: 940
# Number of columns: 13
# First few rows:
#          Year Country of Origin Code Country of Asylum Code  \
# 0  #date+year   #country+code+origin   #country+code+asylum
# 1        2000                    AFG                    TUR
# 2        2000                    DZA                    TUR
# 3        2000                    CHN                    TUR
# 4        2000                    COG                    TUR
#
#   Country of Origin Name Country of Asylum Name             Procedure Type  \
# 0   #country+name+origin   #country+name+asylum  #indicator+procedure_type
# 1            Afghanistan                Türkiye                          U
# 2                Algeria                Türkiye                          U
# 3                  China                Türkiye                          U
# 4                  Congo                Türkiye                          U
#
#               Procedure Name             Application Type Code  \
# 0  #indicator+procedure+name  #indicator+application_type+code
# 1                      UNHCR                                 V
# 2                      UNHCR                                 V
# 3                      UNHCR                                 V
# 4                      UNHCR                                 V
#
#               Application Type             Application Data Type  \
# 0  #indicator+application_type  #indicator+application_data_type
# 1                      Various                                 P
# 2                      Various                                 P
# 3                      Various                                 P
# 4                      Various                                 P
#
#               Application Data        Application Average Persons Per Case  \
# 0  #indicator+application_data  #indicator+application_average_persons+num
# 1                      Persons                                           0
# 2                      Persons                                           0
# 3                      Persons                                           0
# 4                      Persons                                           0
#
#                 Number of Applications
# 0  #inneed+asylum_seekers+applications
# 1                                   81
# 2                                    5
# 3                                   11
# 4                                    5
# --------------------------------------------------
#
# Dataset: Decisions from turkey
# Number of rows: 902
# Number of columns: 16
# First few rows:
#          Year Country of Origin Code Country of Asylum Code  \
# 0  #date+year   #country+code+origin   #country+code+asylum
# 1        2000                    AFG                    TUR
# 2        2000                    DZA                    TUR
# 3        2000                    CHN                    TUR
# 4        2000                    ERI                    TUR
#
#   Country of Origin Name Country of Asylum Name             Procedure Type  \
# 0   #country+name+origin   #country+name+asylum  #indicator+procedure_type
# 1            Afghanistan                Türkiye                          U
# 2                Algeria                Türkiye                          U
# 3                  China                Türkiye                          U
# 4                Eritrea                Türkiye                          U
#
#               Procedure Name             Decision Type Code  \
# 0  #indicator+procedure+name  #indicator+decision_type+code
# 1                      UNHCR                             FI
# 2                      UNHCR                             FI
# 3                      UNHCR                             FI
# 4                      UNHCR                             FI
#
#               Decision Data Type             Decision Data  \
# 0  #indicator+decision_data_type  #indicator+decision_data
# 1                              P                   Persons
# 2                              P                   Persons
# 3                              P                   Persons
# 4                              P                   Persons
#
#         Decisions Average Persons Per Case                         Recognized  \
# 0  #indicator+decision_average_persons+num  #inneed+asylum_seekers+recognized
# 1                                        0                                 29
# 2                                        0                                  0
# 3                                        0                                 14
# 4                                        0                                  0
#
#                   Complementary Protection  \
# 0  #inneed+asylum_seekers+recognized_other
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#                           Otherwise Closed                         Rejected  \
# 0  #inneed+asylum_seekers+otherwise_closed  #inneed+asylum_seekers+rejected
# 1                                       49                               24
# 2                                        5                                0
# 3                                        0                                0
# 4                                        0                               14
#
#                           Total Decided
# 0  #inneed+asylum_seekers+total_decided
# 1                                   102
# 2                                     5
# 3                                    14
# 4                                    14
# --------------------------------------------------
#
# Dataset: Decisions from other countries
# Number of rows: 1687
# Number of columns: 16
# First few rows:
#          Year Country of Origin Code Country of Asylum Code  \
# 0  #date+year   #country+code+origin   #country+code+asylum
# 1        2000                    TUR                    ALB
# 2        2000                    TUR                    AUS
# 3        2000                    TUR                    AUS
# 4        2000                    TUR                    AUT
#
#   Country of Origin Name Country of Asylum Name             Procedure Type  \
# 0   #country+name+origin   #country+name+asylum  #indicator+procedure_type
# 1                Türkiye                Albania                          G
# 2                Türkiye              Australia                          G
# 3                Türkiye              Australia                          G
# 4                Türkiye                Austria                          G
#
#               Procedure Name             Decision Type Code  \
# 0  #indicator+procedure+name  #indicator+decision_type+code
# 1                 Government                             FI
# 2                 Government                             AR
# 3                 Government                             FI
# 4                 Government                             FA
#
#               Decision Data Type             Decision Data  \
# 0  #indicator+decision_data_type  #indicator+decision_data
# 1                              C                     Cases
# 2                              C                     Cases
# 3                              C                     Cases
# 4                              P                   Persons
#
#         Decisions Average Persons Per Case                         Recognized  \
# 0  #indicator+decision_average_persons+num  #inneed+asylum_seekers+recognized
# 1                                        0                                 10
# 2                                        0                                 17
# 3                                        0                                 38
# 4                                        0                                 18
#
#                   Complementary Protection  \
# 0  #inneed+asylum_seekers+recognized_other
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#                           Otherwise Closed                         Rejected  \
# 0  #inneed+asylum_seekers+otherwise_closed  #inneed+asylum_seekers+rejected
# 1                                       30                                0
# 2                                        5                               56
# 3                                        5                               99
# 4                                      157                              165
#
#                           Total Decided
# 0  #inneed+asylum_seekers+total_decided
# 1                                    40
# 2                                    78
# 3                                   142
# 4                                   340
# --------------------------------------------------

# %%
def check_data_quality(name, df):
    print(f"\nDataset: {name}")
    print(f"Total duplicated rows: {df.duplicated().sum()}")
    print(f"Duplicate percentage: {(df.duplicated().sum() / len(df) * 100):.2f}%")
    
    print("\nColumn summary:")
    summary_columns = pd.DataFrame({
        'Type': df.dtypes,
        'Missing Values': df.isnull().sum(),
        'Missing %': (df.isnull().mean() * 100).round(2)
    })
    display(summary_columns)

for name, df in datasets.items():
    check_data_quality(name, df)
# Out:
# Dataset: Applications from turkey
# Total duplicated rows: 6
# Duplicate percentage: 0.34%
#
# Column summary:
#                                         Type  Missing Values  Missing %
# Year                                  object               0       0.00
# Country of Origin Code                object               0       0.00
# Country of Asylum Code                object               0       0.00
# Country of Origin Name                object               0       0.00
# Country of Asylum Name                object               0       0.00
# Procedure Type                        object               0       0.00
# Procedure Name                        object               0       0.00
# Application Type Code                 object               4       0.22
# Application Type                      object               0       0.00
# Application Data Type                 object               0       0.00
# Application Data                      object               0       0.00
# Application Average Persons Per Case  object               0       0.00
# Number of Applications                object               0       0.00
# Dataset: Applications to turkey
# Total duplicated rows: 1
# Duplicate percentage: 0.11%
#
# Column summary:
#                                         Type  Missing Values  Missing %
# Year                                  object               0        0.0
# Country of Origin Code                object               0        0.0
# Country of Asylum Code                object               0        0.0
# Country of Origin Name                object               0        0.0
# Country of Asylum Name                object               0        0.0
# Procedure Type                        object               0        0.0
# Procedure Name                        object               0        0.0
# Application Type Code                 object               0        0.0
# Application Type                      object               0        0.0
# Application Data Type                 object               0        0.0
# Application Data                      object               0        0.0
# Application Average Persons Per Case  object               0        0.0
# Number of Applications                object               0        0.0
# Dataset: Decisions from turkey
# Total duplicated rows: 0
# Duplicate percentage: 0.00%
#
# Column summary:
#                                       Type  Missing Values  Missing %
# Year                                object               0        0.0
# Country of Origin Code              object               0        0.0
# Country of Asylum Code              object               0        0.0
# Country of Origin Name              object               0        0.0
# Country of Asylum Name              object               0        0.0
# Procedure Type                      object               0        0.0
# Procedure Name                      object               0        0.0
# Decision Type Code                  object               0        0.0
# Decision Data Type                  object               0        0.0
# Decision Data                       object               0        0.0
# Decisions Average Persons Per Case  object               0        0.0
# Recognized                          object               0        0.0
# Complementary Protection            object               0        0.0
# Otherwise Closed                    object               0        0.0
# Rejected                            object               0        0.0
# Total Decided                       object               0        0.0
# Dataset: Decisions from other countries
# Total duplicated rows: 0
# Duplicate percentage: 0.00%
#
# Column summary:
#                                       Type  Missing Values  Missing %
# Year                                object               0       0.00
# Country of Origin Code              object               0       0.00
# Country of Asylum Code              object               0       0.00
# Country of Origin Name              object               0       0.00
# Country of Asylum Name              object               0       0.00
# Procedure Type                      object               0       0.00
# Procedure Name                      object               0       0.00
# Decision Type Code                  object              21       1.24
# Decision Data Type                  object               0       0.00
# Decision Data                       object               0       0.00
# Decisions Average Persons Per Case  object               0       0.00
# Recognized                          object               0       0.00
# Complementary Protection            object               0       0.00
# Otherwise Closed                    object               0       0.00
# Rejected                            object               0       0.00
# Total Decided                       object               0       0.00

# %%
def detect_numeric_object_columns(df, threshold=0.9):
    numeric_like_cols = []

    for col in df.select_dtypes(include='object').columns:
        converted = pd.to_numeric(df[col], errors='coerce')
        ratio = converted.notna().mean()

        if ratio >= threshold:
            numeric_like_cols.append(col)

    return numeric_like_cols

print('-' * 50)
print('Object columns turned into numeric in each dataframe:')
print()
for name, df in datasets.items():
    cols_to_convert = detect_numeric_object_columns(df)
    
    df[cols_to_convert] = df[cols_to_convert].apply(
    pd.to_numeric, errors='coerce'
    )
    
    print(f"{name}: {cols_to_convert}")
print('-' * 50)

for name, df in datasets.items():
    check_data_quality(name, df)
# Out:
# --------------------------------------------------
# Object columns turned into numeric in each dataframe:
#
# Applications from turkey: ['Year', 'Application Average Persons Per Case', 'Number of Applications']
# Applications to turkey: ['Year', 'Application Average Persons Per Case', 'Number of Applications']
# Decisions from turkey: ['Year', 'Decisions Average Persons Per Case', 'Recognized', 'Complementary Protection', 'Otherwise Closed', 'Rejected', 'Total Decided']
# Decisions from other countries: ['Year', 'Decisions Average Persons Per Case', 'Recognized', 'Complementary Protection', 'Otherwise Closed', 'Rejected', 'Total Decided']
# --------------------------------------------------
#
# Dataset: Applications from turkey
# Total duplicated rows: 6
# Duplicate percentage: 0.34%
#
# Column summary:
#                                          Type  Missing Values  Missing %
# Year                                  float64               1       0.06
# Country of Origin Code                 object               0       0.00
# Country of Asylum Code                 object               0       0.00
# Country of Origin Name                 object               0       0.00
# Country of Asylum Name                 object               0       0.00
# Procedure Type                         object               0       0.00
# Procedure Name                         object               0       0.00
# Application Type Code                  object               4       0.22
# Application Type                       object               0       0.00
# Application Data Type                  object               0       0.00
# Application Data                       object               0       0.00
# Application Average Persons Per Case  float64               1       0.06
# Number of Applications                float64               1       0.06
# Dataset: Applications to turkey
# Total duplicated rows: 1
# Duplicate percentage: 0.11%
#
# Column summary:
#                                          Type  Missing Values  Missing %
# Year                                  float64               1       0.11
# Country of Origin Code                 object               0       0.00
# Country of Asylum Code                 object               0       0.00
# Country of Origin Name                 object               0       0.00
# Country of Asylum Name                 object               0       0.00
# Procedure Type                         object               0       0.00
# Procedure Name                         object               0       0.00
# Application Type Code                  object               0       0.00
# Application Type                       object               0       0.00
# Application Data Type                  object               0       0.00
# Application Data                       object               0       0.00
# Application Average Persons Per Case  float64               1       0.11
# Number of Applications                float64               1       0.11
# Dataset: Decisions from turkey
# Total duplicated rows: 0
# Duplicate percentage: 0.00%
#
# Column summary:
#                                        Type  Missing Values  Missing %
# Year                                float64               1       0.11
# Country of Origin Code               object               0       0.00
# Country of Asylum Code               object               0       0.00
# Country of Origin Name               object               0       0.00
# Country of Asylum Name               object               0       0.00
# Procedure Type                       object               0       0.00
# Procedure Name                       object               0       0.00
# Decision Type Code                   object               0       0.00
# Decision Data Type                   object               0       0.00
# Decision Data                        object               0       0.00
# Decisions Average Persons Per Case  float64               1       0.11
# Recognized                          float64               1       0.11
# Complementary Protection            float64               1       0.11
# Otherwise Closed                    float64               1       0.11
# Rejected                            float64               1       0.11
# Total Decided                       float64               1       0.11
# Dataset: Decisions from other countries
# Total duplicated rows: 0
# Duplicate percentage: 0.00%
#
# Column summary:
#                                        Type  Missing Values  Missing %
# Year                                float64               1       0.06
# Country of Origin Code               object               0       0.00
# Country of Asylum Code               object               0       0.00
# Country of Origin Name               object               0       0.00
# Country of Asylum Name               object               0       0.00
# Procedure Type                       object               0       0.00
# Procedure Name                       object               0       0.00
# Decision Type Code                   object              21       1.24
# Decision Data Type                   object               0       0.00
# Decision Data                        object               0       0.00
# Decisions Average Persons Per Case  float64               1       0.06
# Recognized                          float64               1       0.06
# Complementary Protection            float64               1       0.06
# Otherwise Closed                    float64               1       0.06
# Rejected                            float64               1       0.06
# Total Decided                       float64               1       0.06

# %%
# NOTE: From this point forward, we use applications_datasets and decisions_datasets 
# instead of the original 'datasets' dict (which remains unchanged as raw data)

important_columns_applications_datasets = ['Number of Applications', 'Year', 'Country of Origin Name', 'Country of Asylum Name']
important_columns_decisions_datasets = ['Recognized', 'Complementary Protection', 'Otherwise Closed', 'Rejected', 'Total Decided', 'Year', 'Country of Origin Name']

for name, df in applications_datasets.items():
    applications_datasets[name] = df.dropna(subset=important_columns_applications_datasets).drop_duplicates()

for name, df in decisions_datasets.items():
    decisions_datasets[name] = df.dropna(subset=important_columns_decisions_datasets).drop_duplicates()

# %%
print("=" * 50)
print("CLEANED DATA SUMMARY")
print("=" * 50)

for name, df in applications_datasets.items():
    print(f"\n{name}:")
    print(f"  Rows: {len(df)}")
    print(f"  Duplicates: {df.duplicated().sum()}")
    print(f"  Missing values in key columns: {df[important_columns_applications_datasets].isnull().sum().sum()}")

for name, df in decisions_datasets.items():
    print(f"\n{name}:")
    print(f"  Rows: {len(df)}")
    print(f"  Duplicates: {df.duplicated().sum()}")
    print(f"  Missing values in key columns: {df[important_columns_decisions_datasets].isnull().sum().sum()}")
# Out:
# ==================================================
# CLEANED DATA SUMMARY
# ==================================================
#
# Applications from turkey:
#   Rows: 1779
#   Duplicates: 0
#   Missing values in key columns: 0
#
# Applications to turkey:
#   Rows: 938
#   Duplicates: 0
#   Missing values in key columns: 0
#
# Decisions from turkey:
#   Rows: 901
#   Duplicates: 0
#   Missing values in key columns: 0
#
# Decisions from other countries:
#   Rows: 1686
#   Duplicates: 0
#   Missing values in key columns: 0

# %%
clean_data_dir = Path("../data/clean")
clean_data_dir.mkdir(exist_ok=True)

all_clean_datasets = {**applications_datasets, **decisions_datasets}

for name, df in all_clean_datasets.items():
    filename = name.replace(" ", "_").lower() + "_clean.csv"
    df.to_csv(clean_data_dir / filename, index=False)
    print(f"Saved: {filename}")
# Out:
# Saved: applications_from_turkey_clean.csv
# Saved: applications_to_turkey_clean.csv
# Saved: decisions_from_turkey_clean.csv
# Saved: decisions_from_other_countries_clean.csv
